# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np
import os
import json
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %%
BASE_DIR = os.path.dirname(os.path.abspath(__file__))
dataset_path = os.path.join(BASE_DIR, "hand_gesture_dataset_processed_9")

# %%
train_dir = os.path.join(dataset_path, "train")
val_dir = os.path.join(dataset_path, "val")
test_dir = os.path.join(dataset_path, "test")

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode='grayscale',
    label_mode='categorical',
    shuffle=True
)

val_data = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode='grayscale',
    label_mode='categorical',
    shuffle=False
)

test_data = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode='grayscale',
    label_mode='categorical',
    shuffle=False
)
# Out:
# Found 557 files belonging to 8 classes.
# Found 160 files belonging to 8 classes.
# Found 80 files belonging to 8 classes.

# %%
class_names = train_data.class_names
print(class_names)
num_classes = len(class_names)
print(f"Number of classes: {num_classes}")
# Out:
# ['Background', 'New Speed 1', 'New Speed 2', 'New Speed 3', 'New Speed 4', 'New Stop Images', 'Pointing Left', 'Pointing Right']
# Number of classes: 8

# %%
with open(os.path.join(BASE_DIR, "class_indices_v3.json"), "w") as f:
    json.dump(train_data.class_names, f)

# %%
model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(50, 50, 1)),  # Normalize pixel values to [0,1]
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# Display the architecture
model.summary()
# Out:
# c:\Users\louis\Documents\Telerobotics\computer_vision_speed_control\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 50, 50, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 50, 50, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 25, 25, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 25, 25, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,179,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,204,104 (4.59 MB)
#  Trainable params: 1,204,104 (4.59 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
checkpoint_path = os.path.join(BASE_DIR, "hand_gesture_model_best.keras")
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
callbacks = [checkpoint, earlystop]

# %%
print("\nTraining the model...")
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=30,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Training the model...
# Epoch 1/30
# 17/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2932 - loss: 1.8906
# Epoch 1: val_loss improved from None to 0.93496, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 1: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.4327 - loss: 1.6019 - val_accuracy: 0.6250 - val_loss: 0.9350
# Epoch 2/30
# 14/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6492 - loss: 0.9817
# Epoch 2: val_loss improved from 0.93496 to 0.56269, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 2: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7343 - loss: 0.7807 - val_accuracy: 0.7875 - val_loss: 0.5627
# Epoch 3/30
# 17/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7723 - loss: 0.6156
# Epoch 3: val_loss did not improve from 0.56269
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8115 - loss: 0.5412 - val_accuracy: 0.7688 - val_loss: 0.7591
# Epoch 4/30
# 17/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8345 - loss: 0.5188
# Epoch 4: val_loss improved from 0.56269 to 0.35624, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 4: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8671 - loss: 0.4518 - val_accuracy: 0.8938 - val_loss: 0.3562
# Epoch 5/30
# 15/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9142 - loss: 0.2670
# Epoch 5: val_loss improved from 0.35624 to 0.34765, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 5: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9120 - loss: 0.2526 - val_accuracy: 0.8938 - val_loss: 0.3477
# Epoch 6/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9593 - loss: 0.1518
# Epoch 6: val_loss improved from 0.34765 to 0.32784, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 6: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9497 - loss: 0.1755 - val_accuracy: 0.9250 - val_loss: 0.3278
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9516 - loss: 0.1668
# Epoch 7: val_loss did not improve from 0.32784
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9461 - loss: 0.1591 - val_accuracy: 0.9125 - val_loss: 0.3746
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9520 - loss: 0.1272
# Epoch 8: val_loss improved from 0.32784 to 0.24557, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 8: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9605 - loss: 0.1324 - val_accuracy: 0.9312 - val_loss: 0.2456
# Epoch 9/30
# 17/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9812 - loss: 0.0642
# Epoch 9: val_loss improved from 0.24557 to 0.22637, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 9: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9820 - loss: 0.0800 - val_accuracy: 0.9438 - val_loss: 0.2264
# Epoch 10/30
# 17/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9946 - loss: 0.0483
# Epoch 10: val_loss improved from 0.22637 to 0.20600, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 10: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9928 - loss: 0.0533 - val_accuracy: 0.9563 - val_loss: 0.2060
# Epoch 11/30
# 17/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9920 - loss: 0.0419
# Epoch 11: val_loss did not improve from 0.20600
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9910 - loss: 0.0428 - val_accuracy: 0.9563 - val_loss: 0.2281
# Epoch 12/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9970 - loss: 0.0235
# Epoch 12: val_loss did not improve from 0.20600
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9982 - loss: 0.0210 - val_accuracy: 0.9500 - val_loss: 0.2248
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9999 - loss: 0.0188
# Epoch 13: val_loss did not improve from 0.20600
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9982 - loss: 0.0223 - val_accuracy: 0.9500 - val_loss: 0.2315
# Epoch 14/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9556 - loss: 0.1137
# Epoch 14: val_loss improved from 0.20600 to 0.19806, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 14: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9605 - loss: 0.1043 - val_accuracy: 0.9688 - val_loss: 0.1981
# Epoch 15/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9936 - loss: 0.0346
# Epoch 15: val_loss improved from 0.19806 to 0.17574, saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
#
# Epoch 15: finished saving model to c:\Users\louis\Documents\Telerobotics\hand_gesture_model_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9910 - loss: 0.0416 - val_accuracy: 0.9563 - val_loss: 0.1757
# Epoch 16/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 16: val_loss did not improve from 0.17574
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9982 - loss: 0.0204 - val_accuracy: 0.9563 - val_loss: 0.2342
# Epoch 17/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9979 - loss: 0.0107
# Epoch 17: val_loss did not improve from 0.17574
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9982 - loss: 0.0092 - val_accuracy: 0.9563 - val_loss: 0.2478
# Epoch 18/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9985 - loss: 0.0100
# Epoch 18: val_loss did not improve from 0.17574
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9982 - loss: 0.0108 - val_accuracy: 0.9563 - val_loss: 0.2260
# Epoch 19/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 19: val_loss did not improve from 0.17574
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9625 - val_loss: 0.2347
# Epoch 20/30
# 16/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 20: val_loss did not improve from 0.17574
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9625 - val_loss: 0.2425
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
print("\nEvaluating on test data...")
test_loss, test_accuracy = model.evaluate(test_data)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Evaluating on test data...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9750 - loss: 0.0288
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9750 - loss: 0.0288
# Test Loss: 0.0288
# Test Accuracy: 0.9750

# %%
y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for _, y in test_data], axis=0)
preds = model.predict(test_data, verbose=1)
y_pred = np.argmax(preds, axis=1)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
os.makedirs(os.path.join(BASE_DIR, "models", "model_9"), exist_ok=True)
os.makedirs(os.path.join(BASE_DIR, "results", "model_9"), exist_ok=True)

# %%
cm = confusion_matrix(y_true, y_pred)
cr = classification_report(y_true, y_pred, target_names=class_names)
print("\nConfusion Matrix:\n", cm)
print("\nClassification Report:\n", cr)
with open(os.path.join(BASE_DIR, "results", "model_9", "classification_report.txt"), "w") as f:
    f.write("Confusion Matrix:\n")
    f.write(str(cm))
    f.write("\n\nClassification Report:\n")
    f.write(cr)

# Plot confusion matrix (raw counts) and normalized version
tick_marks = np.arange(len(class_names))

# Raw confusion matrix heatmap
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xticks(tick_marks, class_names, rotation=45, ha='right')
plt.yticks(tick_marks, class_names)
thresh = cm.max() / 2.0 if cm.size else 0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, f"{cm[i, j]:d}", ha='center',
            color='white' if cm[i, j] > thresh else 'black')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.savefig(os.path.join(BASE_DIR, 'results', 'model_9', 'confusion_matrix.png'))
plt.close()

# Normalized confusion matrix (rows sum to 1)
cm_norm = cm.astype('float')
row_sums = cm_norm.sum(axis=1)[:, np.newaxis]
with np.errstate(divide='ignore', invalid='ignore'):
    cm_norm = np.divide(cm_norm, row_sums)
cm_norm = np.nan_to_num(cm_norm)

plt.figure(figsize=(8, 6))
plt.imshow(cm_norm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Normalized Confusion Matrix')
plt.colorbar()
plt.xticks(tick_marks, class_names, rotation=45, ha='right')
plt.yticks(tick_marks, class_names)
thresh = cm_norm.max() / 2.0 if cm_norm.size else 0
for i, j in np.ndindex(cm_norm.shape):
    plt.text(j, i, f"{cm_norm[i, j]:.2f}", ha='center',
            color='white' if cm_norm[i, j] > thresh else 'black')
plt.ylabel('True label')
plt.xlabel('Predicted label (normalized)')
plt.tight_layout()
plt.savefig(os.path.join(BASE_DIR, 'results', 'model_9', 'confusion_matrix_normalized.png'))
plt.close()

# Plot training curves
plt.figure()
plt.plot(history.history.get('loss', []), label='train_loss')
plt.plot(history.history.get('val_loss', []), label='val_loss')
plt.legend()
plt.title('Loss')
plt.savefig(os.path.join(BASE_DIR, 'results', 'model_9', 'loss_curve.png'))
plt.close()

plt.figure()
plt.plot(history.history.get('accuracy', []), label='train_acc')
plt.plot(history.history.get('val_accuracy', []), label='val_acc')
plt.legend()
plt.title('Accuracy')
plt.savefig(os.path.join(BASE_DIR, 'results', 'model_9', 'accuracy_curve.png'))
plt.close()

# Save the trained model
model_save_path = os.path.join(BASE_DIR, "models", "model_9", "hand_gesture_model_9.keras")
model.save(model_save_path)
print(f"\nModel saved to {model_save_path}")
# Out:
# Confusion Matrix:
#  [[10  0  0  0  0  0  0  0]
#  [ 0  9  1  0  0  0  0  0]
#  [ 0  0  9  0  0  1  0  0]
#  [ 0  0  0 10  0  0  0  0]
#  [ 0  0  0  0 10  0  0  0]
#  [ 0  0  0  0  0 10  0  0]
#  [ 0  0  0  0  0  0 10  0]
#  [ 0  0  0  0  0  0  0 10]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#      Background       1.00      1.00      1.00        10
#     New Speed 1       1.00      0.90      0.95        10
#     New Speed 2       0.90      0.90      0.90        10
#     New Speed 3       1.00      1.00      1.00        10
#     New Speed 4       1.00      1.00      1.00        10
# New Stop Images       0.91      1.00      0.95        10
#   Pointing Left       1.00      1.00      1.00        10
#  Pointing Right       1.00      1.00      1.00        10
#
#        accuracy                           0.97        80
#       macro avg       0.98      0.97      0.97        80
#    weighted avg       0.98      0.97      0.97        80
#
#
# Model saved to c:\Users\louis\Documents\Telerobotics\models\model_9\hand_gesture_model_9.keras

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open(os.path.join(BASE_DIR, "models", "model_9", "model_9.tflite"), 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\louis\AppData\Local\Temp\tmps0eg4u25\assets
# INFO:tensorflow:Assets written to: C:\Users\louis\AppData\Local\Temp\tmps0eg4u25\assets
# Saved artifact at 'C:\Users\louis\AppData\Local\Temp\tmps0eg4u25'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 50, 50, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   2976847018128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847018896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847019280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847018320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847019472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847019088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847019664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847282448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2976847282832: TensorSpec(shape=(), dtype=tf.resource, name=None)
