# %% [markdown]
# Connected to computer_vision_speed_control_env (3.11.15) (Python 3.11.15)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np
import os
import json
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %%
BASE_DIR = os.path.dirname(os.path.abspath(__file__))
dataset_path = os.path.join(BASE_DIR, "hand_gesture_dataset_processed_12")

# %%
train_dir = os.path.join(dataset_path, "train")
val_dir = os.path.join(dataset_path, "val")
test_dir = os.path.join(dataset_path, "test")

# %%
train_dir = os.path.join(dataset_path, "train")
val_dir = os.path.join(dataset_path, "val")
test_dir = os.path.join(dataset_path, "test")

# Load data in batches
train_data = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode="grayscale",
    label_mode="categorical",
    shuffle=True,
)

val_data = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode="grayscale",
    label_mode="categorical",
    shuffle=False,
)

test_data = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode="grayscale",
    label_mode="categorical",
    shuffle=False,
)
# Out:
# Found 4760 files belonging to 8 classes.
# Found 1361 files belonging to 8 classes.
# Found 680 files belonging to 8 classes.

# %%
class_names = train_data.class_names
print(class_names)
num_classes = len(class_names)
print(f"Number of classes: {num_classes}")
# Out:
# ['left', 'none', 'right', 'spd1', 'spd2', 'spd3', 'spd4', 'stop']
# Number of classes: 8

# %%
with open(os.path.join(BASE_DIR, "class_indices_v4.json"), "w") as f:
    json.dump(train_data.class_names, f)

model = models.Sequential(
    [
        layers.Rescaling(
            1.0 / 255, input_shape=(50, 50, 1)
        ),  # Normalize pixel values to [0,1]
        layers.Conv2D(16, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding="same", activation="relu"),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(128, activation="relu"),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 50, 50, 1)         0
#
#  conv2d (Conv2D)             (None, 50, 50, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 25, 25, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dropout (Dropout)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 1204104 (4.59 MB)
# Trainable params: 1204104 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
os.makedirs(os.path.join(BASE_DIR, "models", "model_12"), exist_ok=True)
os.makedirs(os.path.join(BASE_DIR, "results", "model_12"), exist_ok=True)

# %%
checkpoint_path = os.path.join(
    BASE_DIR, "models", "model_12", "hand_gesture_model_best.keras"
)
checkpoint = ModelCheckpoint(
    checkpoint_path, monitor="val_loss", save_best_only=True, verbose=1
)
earlystop = EarlyStopping(
    monitor="val_loss", patience=50, restore_best_weights=True, verbose=1
)
callbacks = [checkpoint, earlystop]

print("\nTraining the model...")
history = model.fit(
    train_data, validation_data=val_data, epochs=200, callbacks=callbacks, verbose=1
)
# Out:
# Training the model...
# Epoch 1/200
# 140/149 [===========================>..] - ETA: 0s - loss: 0.1241 - accuracy: 0.9629
# Epoch 1: val_loss improved from inf to 0.00098, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1180 - accuracy: 0.9647 - val_loss: 9.8221e-04 - val_accuracy: 1.0000
# Epoch 2/200
# 139/149 [==========================>...] - ETA: 0s - loss: 0.0043 - accuracy: 0.9989
# Epoch 2: val_loss did not improve from 0.00098
# 149/149 [==============================] - 1s 5ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 3/200
# 148/149 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9996
# Epoch 3: val_loss improved from 0.00098 to 0.00001, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 5.8298e-06 - val_accuracy: 1.0000
# Epoch 4/200
# 144/149 [===========================>..] - ETA: 0s - loss: 2.9734e-05 - accuracy: 1.0000
# Epoch 4: val_loss improved from 0.00001 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 4.3780e-05 - accuracy: 1.0000 - val_loss: 2.4720e-06 - val_accuracy: 1.0000
# Epoch 5/200
# 144/149 [===========================>..] - ETA: 0s - loss: 2.5794e-05 - accuracy: 1.0000
# Epoch 5: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.5251e-05 - accuracy: 1.0000 - val_loss: 1.3077e-06 - val_accuracy: 1.0000
# Epoch 6/200
# 144/149 [===========================>..] - ETA: 0s - loss: 1.4673e-05 - accuracy: 1.0000
# Epoch 6: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.4281e-05 - accuracy: 1.0000 - val_loss: 8.5601e-07 - val_accuracy: 1.0000
# Epoch 7/200
# 144/149 [===========================>..] - ETA: 0s - loss: 7.9744e-06 - accuracy: 1.0000
# Epoch 7: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 8.2411e-06 - accuracy: 1.0000 - val_loss: 6.1742e-07 - val_accuracy: 1.0000
# Epoch 8/200
# 145/149 [============================>.] - ETA: 0s - loss: 5.4444e-06 - accuracy: 1.0000
# Epoch 8: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 5.4993e-06 - accuracy: 1.0000 - val_loss: 4.4460e-07 - val_accuracy: 1.0000
# Epoch 9/200
# 143/149 [===========================>..] - ETA: 0s - loss: 8.2274e-06 - accuracy: 1.0000
# Epoch 9: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 8.4219e-06 - accuracy: 1.0000 - val_loss: 4.2551e-07 - val_accuracy: 1.0000
# Epoch 10/200
# 144/149 [===========================>..] - ETA: 0s - loss: 4.2040e-06 - accuracy: 1.0000
# Epoch 10: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 4.3005e-06 - accuracy: 1.0000 - val_loss: 3.0639e-07 - val_accuracy: 1.0000
# Epoch 11/200
# 145/149 [============================>.] - ETA: 0s - loss: 4.6380e-06 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 5.3416e-06 - accuracy: 1.0000 - val_loss: 2.4026e-07 - val_accuracy: 1.0000
# Epoch 12/200
# 144/149 [===========================>..] - ETA: 0s - loss: 3.2906e-06 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 3.2394e-06 - accuracy: 1.0000 - val_loss: 1.8867e-07 - val_accuracy: 1.0000
# Epoch 13/200
# 144/149 [===========================>..] - ETA: 0s - loss: 2.2545e-06 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.2825e-06 - accuracy: 1.0000 - val_loss: 1.6896e-07 - val_accuracy: 1.0000
# Epoch 14/200
# 144/149 [===========================>..] - ETA: 0s - loss: 2.5609e-06 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.7092e-06 - accuracy: 1.0000 - val_loss: 1.2788e-07 - val_accuracy: 1.0000
# Epoch 15/200
# 144/149 [===========================>..] - ETA: 0s - loss: 2.1309e-06 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.0788e-06 - accuracy: 1.0000 - val_loss: 1.0187e-07 - val_accuracy: 1.0000
# Epoch 16/200
# 145/149 [============================>.] - ETA: 0s - loss: 2.4439e-06 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.4009e-06 - accuracy: 1.0000 - val_loss: 9.3370e-08 - val_accuracy: 1.0000
# Epoch 17/200
# 144/149 [===========================>..] - ETA: 0s - loss: 3.1553e-06 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 3.0668e-06 - accuracy: 1.0000 - val_loss: 7.3312e-08 - val_accuracy: 1.0000
# Epoch 18/200
# 142/149 [===========================>..] - ETA: 0s - loss: 1.8107e-06 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.7870e-06 - accuracy: 1.0000 - val_loss: 6.1137e-08 - val_accuracy: 1.0000
# Epoch 19/200
# 145/149 [============================>.] - ETA: 0s - loss: 8.5860e-07 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 8.6102e-07 - accuracy: 1.0000 - val_loss: 5.3692e-08 - val_accuracy: 1.0000
# Epoch 20/200
# 144/149 [===========================>..] - ETA: 0s - loss: 1.2493e-06 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.2157e-06 - accuracy: 1.0000 - val_loss: 4.6422e-08 - val_accuracy: 1.0000
# Epoch 21/200
# 145/149 [============================>.] - ETA: 0s - loss: 1.5135e-06 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.5400e-06 - accuracy: 1.0000 - val_loss: 4.1079e-08 - val_accuracy: 1.0000
# Epoch 22/200
# 144/149 [===========================>..] - ETA: 0s - loss: 1.3977e-06 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.3872e-06 - accuracy: 1.0000 - val_loss: 3.5824e-08 - val_accuracy: 1.0000
# Epoch 23/200
# 145/149 [============================>.] - ETA: 0s - loss: 5.5266e-07 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 5.4632e-07 - accuracy: 1.0000 - val_loss: 2.6102e-08 - val_accuracy: 1.0000
# Epoch 24/200
# 145/149 [============================>.] - ETA: 0s - loss: 6.8584e-07 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 6.8412e-07 - accuracy: 1.0000 - val_loss: 1.6642e-08 - val_accuracy: 1.0000
# Epoch 25/200
# 145/149 [============================>.] - ETA: 0s - loss: 5.0448e-07 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 5.0138e-07 - accuracy: 1.0000 - val_loss: 3.3722e-08 - val_accuracy: 1.0000
# Epoch 26/200
# 139/149 [==========================>...] - ETA: 0s - loss: 5.7585e-07 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 5.9835e-07 - accuracy: 1.0000 - val_loss: 2.6715e-08 - val_accuracy: 1.0000
# Epoch 27/200
# 145/149 [============================>.] - ETA: 0s - loss: 5.6123e-07 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss:
val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 2.1332e-06 - accuracy: 1.0000 - val_loss: 2.2773e-08 - val_accuracy: 1.0000
# Epoch 72/200
# 145/149 [============================>.] - ETA: 0s - loss: 1.5096e-06 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 1.6638e-06 - accuracy: 1.0000 - val_loss: 2.1459e-08 - val_accuracy: 1.0000
# Epoch 73/200
# 141/149 [===========================>..] - ETA: 0s - loss: 1.1463e-06 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 1.1256e-06 - accuracy: 1.0000 - val_loss: 1.0248e-08 - val_accuracy: 1.0000
# Epoch 74/200
# 145/149 [============================>.] - ETA: 0s - loss: 7.3215e-07 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 7.2373e-07 - accuracy: 1.0000 - val_loss: 7.4451e-09 - val_accuracy: 1.0000
# Epoch 75/200
# 145/149 [============================>.] - ETA: 0s - loss: 4.2675e-07 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 4.4617e-07 - accuracy: 1.0000 - val_loss: 6.0437e-09 - val_accuracy: 1.0000
# Epoch 76/200
# 144/149 [===========================>..] - ETA: 0s - loss: 6.3366e-07 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 7.0520e-07 - accuracy: 1.0000 - val_loss: 4.6422e-09 - val_accuracy: 1.0000
# Epoch 77/200
# 145/149 [============================>.] - ETA: 0s - loss: 8.2417e-07 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 8.1018e-07 - accuracy: 1.0000 - val_loss: 4.1167e-09 - val_accuracy: 1.0000
# Epoch 78/200
# 145/149 [============================>.] - ETA: 0s - loss: 6.0887e-07 - accuracy: 1.0000
# Epoch 78: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 6.0477e-07 - accuracy: 1.0000 - val_loss: 3.5036e-09 - val_accuracy: 1.0000
# Epoch 79/200
# 145/149 [============================>.] - ETA: 0s - loss: 6.5045e-07 - accuracy: 1.0000
# Epoch 79: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 6.3588e-07 - accuracy: 1.0000 - val_loss: 3.0656e-09 - val_accuracy: 1.0000
# Epoch 80/200
# 145/149 [============================>.] - ETA: 0s - loss: 4.7209e-07 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 4.7183e-07 - accuracy: 1.0000 - val_loss: 2.7153e-09 - val_accuracy: 1.0000
# Epoch 81/200
# 142/149 [===========================>..] - ETA: 0s - loss: 3.7484e-07 - accuracy: 1.0000
# Epoch 81: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 3.7238e-07 - accuracy: 1.0000 - val_loss: 2.4525e-09 - val_accuracy: 1.0000
# Epoch 82/200
# 141/149 [===========================>..] - ETA: 0s - loss: 6.3370e-07 - accuracy: 1.0000
# Epoch 82: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 6.1331e-07 - accuracy: 1.0000 - val_loss: 2.4525e-09 - val_accuracy: 1.0000
# Epoch 83/200
# 143/149 [===========================>..] - ETA: 0s - loss: 4.7280e-07 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 4.5731e-07 - accuracy: 1.0000 - val_loss: 2.3649e-09 - val_accuracy: 1.0000
# Epoch 84/200
# 142/149 [===========================>..] - ETA: 0s - loss: 2.3094e-07 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 2.5051e-07 - accuracy: 1.0000 - val_loss: 1.9270e-09 - val_accuracy: 1.0000
# Epoch 85/200
# 148/149 [============================>.] - ETA: 0s - loss: 1.6517e-06 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 1.6433e-06 - accuracy: 1.0000 - val_loss: 1.3138e-09 - val_accuracy: 1.0000
# Epoch 86/200
# 145/149 [============================>.] - ETA: 0s - loss: 6.1098e-07 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 6.3942e-07 - accuracy: 1.0000 - val_loss: 1.7518e-09 - val_accuracy: 1.0000
# Epoch 87/200
# 138/149 [==========================>...] - ETA: 0s - loss: 6.8797e-07 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 7.3590e-07 - accuracy: 1.0000 - val_loss: 1.5766e-09 - val_accuracy: 1.0000
# Epoch 88/200
# 138/149 [==========================>...] - ETA: 0s - loss: 1.3233e-07 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.00000
# Restoring model weights from the end of the best epoch: 38.
# 149/149 [==============================] - 1s 5ms/step - loss: 1.6233e-07 - accuracy: 1.0000 - val_loss: 1.1387e-09 - val_accuracy: 1.0000
# Epoch 88: early stopping

# %%
print("\nEvaluating on test data...")
test_loss, test_accuracy = model.evaluate(test_data)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Evaluating on test data...
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Test Loss: 0.0000
# Test Accuracy: 1.0000

# %%
y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for _, y in test_data], axis=0)
preds = model.predict(test_data, verbose=1)
y_pred = np.argmax(preds, axis=1)

# Print and save confusion matrix and classification report
cm = confusion_matrix(y_true, y_pred)
cr = classification_report(y_true, y_pred, target_names=class_names)
print("\nConfusion Matrix:\n", cm)
print("\nClassification Report:\n", cr)
with open(
    os.path.join(BASE_DIR, "results", "model_12", "classification_report.txt"), "w"
) as f:
    f.write("Confusion Matrix:\n")
    f.write(str(cm))
    f.write("\n\nClassification Report:\n")
    f.write(cr)

# Plot confusion matrix (raw counts) and normalized version
tick_marks = np.arange(len(class_names))

# Raw confusion matrix heatmap
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
plt.xticks(tick_marks, class_names, rotation=45, ha="right")
plt.yticks(tick_marks, class_names)
thresh = cm.max() / 2.0 if cm.size else 0
for i, j in np.ndindex(cm.shape):
    plt.text(
        j,
        i,
        f"{cm[i, j]:d}",
        ha="center",
        color="white" if cm[i, j] > thresh else "black",
    )
plt.ylabel("True label")
plt.xlabel("Predicted label")
plt.tight_layout()
plt.savefig(os.path.join(BASE_DIR, "results", "model_12", "confusion_matrix.png"))
plt.close()

# Normalized confusion matrix (rows sum to 1)
cm_norm = cm.astype("float")
row_sums = cm_norm.sum(axis=1)[:, np.newaxis]
with np.errstate(divide="ignore", invalid="ignore"):
    cm_norm = np.divide(cm_norm, row_sums)
cm_norm = np.nan_to_num(cm_norm)

plt.figure(figsize=(8, 6))
plt.imshow(cm_norm, interpolation="nearest", cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.colorbar()
plt.xticks(tick_marks, class_names, rotation=45, ha="right")
plt.yticks(tick_marks, class_names)
thresh = cm_norm.max() / 2.0 if cm_norm.size else 0
for i, j in np.ndindex(cm_norm.shape):
    plt.text(
        j,
        i,
        f"{cm_norm[i, j]:.2f}",
        ha="center",
        color="white" if cm_norm[i, j] > thresh else "black",
    )
plt.ylabel("True label")
plt.xlabel("Predicted label (normalized)")
plt.tight_layout()
plt.savefig(
    os.path.join(BASE_DIR, "results", "model_12", "confusion_matrix_normalized.png")
)
plt.close()

# Plot training curves
plt.figure()
plt.plot(history.history.get("loss", []), label="train_loss")
plt.plot(history.history.get("val_loss", []), label="val_loss")
plt.legend()
plt.title("Loss")
plt.savefig(os.path.join(BASE_DIR, "results", "model_12", "loss_curve.png"))
plt.close()

plt.figure()
plt.plot(history.history.get("accuracy", []), label="train_acc")
plt.plot(history.history.get("val_accuracy", []), label="val_acc")
plt.legend()
plt.title("Accuracy")
plt.savefig(os.path.join(BASE_DIR, "results", "model_12", "accuracy_curve.png"))
plt.close()

# Save the trained model
model_save_path = os.path.join(
    BASE_DIR, "models", "model_12", "hand_gesture_model_12.keras"
)
model.save(model_save_path)
print(f"\nModel saved to {model_save_path}")

# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open(os.path.join(BASE_DIR, "models", "model_12", "model_12.tflite"), "wb") as f:
    f.write(tflite_model)
# Out:
# 22/22 [==============================] - 0s 2ms/step
#
# Confusion Matrix:
#  [[85  0  0  0  0  0  0  0]
#  [ 0 85  0  0  0  0  0  0]
#  [ 0  0 85  0  0  0  0  0]
#  [ 0  0  0 85  0  0  0  0]
#  [ 0  0  0  0 85  0  0  0]
#  [ 0  0  0  0  0 85  0  0]
#  [ 0  0  0  0  0  0 85  0]
#  [ 0  0  0  0  0  0  0 85]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         left       1.00      1.00      1.00        85
#         none       1.00      1.00      1.00        85
#        right       1.00      1.00      1.00        85
#         spd1       1.00      1.00      1.00        85
#         spd2       1.00      1.00      1.00        85
#         spd3       1.00      1.00      1.00        85
#         spd4       1.00      1.00      1.00        85
#         stop       1.00      1.00      1.00        85
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
#
# Model saved to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_12/hand_gesture_model_12.keras
# INFO:tensorflow:Assets written to: /var/folders/qg/vs03rg_n2p92q6n_gszm9_2r0000gn/T/tmpzgfvcjoq/assets
# INFO:tensorflow:Assets written to: /var/folders/qg/vs03rg_n2p92q6n_gszm9_2r0000gn/T/tmpzgfvcjoq/assets
# 2026-04-26 14:59:57.726297: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-04-26 14:59:57.726308: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 11, Total Ops 23, % non-converted = 47.83 %
#  * 11 ARITH ops
#
# - arith.constant:   11 occurrences  (f32: 10, i32: 1)
#
#
#
#   (f32: 3)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 1)
