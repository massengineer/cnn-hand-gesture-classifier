# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np
import os
import json
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %%
BASE_DIR = os.path.dirname(os.path.abspath(__file__))
dataset_path = os.path.join(BASE_DIR, "hand_gesture_dataset_processed_11")

# %%
train_dir = os.path.join(dataset_path, "train")
val_dir = os.path.join(dataset_path, "val")
test_dir = os.path.join(dataset_path, "test")

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode="grayscale",
    label_mode="categorical",
    shuffle=True,
)

val_data = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode="grayscale",
    label_mode="categorical",
    shuffle=False,
)

test_data = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(50, 50),
    batch_size=32,
    color_mode="grayscale",
    label_mode="categorical",
    shuffle=False,
)
# Out:
# Found 4760 files belonging to 8 classes.
# Found 1361 files belonging to 8 classes.
# Found 680 files belonging to 8 classes.

# %%
class_names = train_data.class_names
print(class_names)
num_classes = len(class_names)
print(f"Number of classes: {num_classes}")
# Out:
# ['left', 'none', 'right', 'spd1', 'spd2', 'spd3', 'spd4', 'stop']
# Number of classes: 8

# %%
with open(os.path.join(BASE_DIR, "class_indices_v4.json"), "w") as f:
    json.dump(train_data.class_names, f)

model = models.Sequential(
    [
        layers.Rescaling(
            1.0 / 255, input_shape=(50, 50, 1)
        ),  # Normalize pixel values to [0,1]
        layers.Conv2D(16, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding="same", activation="relu"),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(128, activation="relu"),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 50, 50, 1)         0
#
#  conv2d (Conv2D)             (None, 50, 50, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 25, 25, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dropout (Dropout)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 1204104 (4.59 MB)
# Trainable params: 1204104 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
checkpoint_path = os.path.join(BASE_DIR, "hand_gesture_model_best.keras")
checkpoint = ModelCheckpoint(
    checkpoint_path, monitor="val_loss", save_best_only=True, verbose=1
)
earlystop = EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True, verbose=1
)
callbacks = [checkpoint, earlystop]

print("\nTraining the model...")
history = model.fit(
    train_data, validation_data=val_data, epochs=30, callbacks=callbacks, verbose=1
)
# Out:
# Training the model...
# Epoch 1/30
# 139/149 [==========================>...] - ETA: 0s - loss: 0.1644 - accuracy: 0.9503
# Epoch 1: val_loss improved from inf to 0.00008, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 0.1538 - accuracy: 0.9536 - val_loss: 8.4495e-05 - val_accuracy: 1.0000
# Epoch 2/30
# 140/149 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 0.9993
# Epoch 2: val_loss improved from 0.00008 to 0.00001, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 5.3657e-06 - val_accuracy: 1.0000
# Epoch 3/30
# 141/149 [===========================>..] - ETA: 0s - loss: 7.3921e-04 - accuracy: 0.9998
# Epoch 3: val_loss improved from 0.00001 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 7.0368e-04 - accuracy: 0.9998 - val_loss: 2.3716e-06 - val_accuracy: 1.0000
# Epoch 4/30
# 138/149 [==========================>...] - ETA: 0s - loss: 0.0052 - accuracy: 0.9982
# Epoch 4: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 1.4058e-04 - val_accuracy: 1.0000
# Epoch 5/30
# 141/149 [===========================>..] - ETA: 0s - loss: 0.0115 - accuracy: 0.9962
# Epoch 5: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 1.2175e-06 - val_accuracy: 1.0000
# Epoch 6/30
# 144/149 [===========================>..] - ETA: 0s - loss: 2.6667e-04 - accuracy: 1.0000
# Epoch 6: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.5833e-04 - accuracy: 1.0000 - val_loss: 3.8662e-07 - val_accuracy: 1.0000
# Epoch 7/30
# 140/149 [===========================>..] - ETA: 0s - loss: 2.8630e-05 - accuracy: 1.0000
# Epoch 7: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.7029e-05 - accuracy: 1.0000 - val_loss: 1.7255e-07 - val_accuracy: 1.0000
# Epoch 8/30
# 144/149 [===========================>..] - ETA: 0s - loss: 1.5505e-05 - accuracy: 1.0000
# Epoch 8: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.5089e-05 - accuracy: 1.0000 - val_loss: 1.0248e-07 - val_accuracy: 1.0000
# Epoch 9/30
# 142/149 [===========================>..] - ETA: 0s - loss: 1.3543e-05 - accuracy: 1.0000
# Epoch 9: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.2947e-05 - accuracy: 1.0000 - val_loss: 6.4028e-08 - val_accuracy: 1.0000
# Epoch 10/30
# 144/149 [===========================>..] - ETA: 0s - loss: 7.0760e-06 - accuracy: 1.0000
# Epoch 10: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 6.8791e-06 - accuracy: 1.0000 - val_loss: 4.1342e-08 - val_accuracy: 1.0000
# Epoch 11/30
# 142/149 [===========================>..] - ETA: 0s - loss: 2.7201e-06 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.6473e-06 - accuracy: 1.0000 - val_loss: 3.1707e-08 - val_accuracy: 1.0000
# Epoch 12/30
# 142/149 [===========================>..] - ETA: 0s - loss: 3.8319e-06 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 3.6946e-06 - accuracy: 1.0000 - val_loss: 2.3299e-08 - val_accuracy: 1.0000
# Epoch 13/30
# 144/149 [===========================>..] - ETA: 0s - loss: 3.0490e-06 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 3.0108e-06 - accuracy: 1.0000 - val_loss: 1.8744e-08 - val_accuracy: 1.0000
# Epoch 14/30
# 144/149 [===========================>..] - ETA: 0s - loss: 3.0247e-06 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.9381e-06 - accuracy: 1.0000 - val_loss: 1.4102e-08 - val_accuracy: 1.0000
# Epoch 15/30
# 144/149 [===========================>..] - ETA: 0s - loss: 2.5589e-06 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.4828e-06 - accuracy: 1.0000 - val_loss: 1.0423e-08 - val_accuracy: 1.0000
# Epoch 16/30
# 144/149 [===========================>..] - ETA: 0s - loss: 2.2322e-06 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 2.2104e-06 - accuracy: 1.0000 - val_loss: 8.4086e-09 - val_accuracy: 1.0000
# Epoch 17/30
# 143/149 [===========================>..] - ETA: 0s - loss: 1.6113e-06 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.5662e-06 - accuracy: 1.0000 - val_loss: 6.4816e-09 - val_accuracy: 1.0000
# Epoch 18/30
# 145/149 [============================>.] - ETA: 0s - loss: 1.1637e-06 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.1425e-06 - accuracy: 1.0000 - val_loss: 5.3430e-09 - val_accuracy: 1.0000
# Epoch 19/30
# 139/149 [==========================>...] - ETA: 0s - loss: 1.3015e-06 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.2626e-06 - accuracy: 1.0000 - val_loss: 4.5547e-09 - val_accuracy: 1.0000
# Epoch 20/30
# 144/149 [===========================>..] - ETA: 0s - loss: 1.1780e-06 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.1567e-06 - accuracy: 1.0000 - val_loss: 3.3284e-09 - val_accuracy: 1.0000
# Epoch 21/30
# 144/149 [===========================>..] - ETA: 0s - loss: 1.1300e-06 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.0968e-06 - accuracy: 1.0000 - val_loss: 2.8905e-09 - val_accuracy: 1.0000
# Epoch 22/30
# 145/149 [============================>.] - ETA: 0s - loss: 8.6404e-07 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 8.6344e-07 - accuracy: 1.0000 - val_loss: 2.1021e-09 - val_accuracy: 1.0000
# Epoch 23/30
# 142/149 [===========================>..] - ETA: 0s - loss: 1.0631e-06 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.0262e-06 - accuracy: 1.0000 - val_loss: 1.7518e-09 - val_accuracy: 1.0000
# Epoch 24/30
# 144/149 [===========================>..] - ETA: 0s - loss: 7.6216e-07 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 7.6499e-07 - accuracy: 1.0000 - val_loss: 1.4014e-09 - val_accuracy: 1.0000
# Epoch 25/30
# 144/149 [===========================>..] - ETA: 0s - loss: 7.0577e-07 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 1.0335e-06 - accuracy: 1.0000 - val_loss: 1.1387e-09 - val_accuracy: 1.0000
# Epoch 26/30
# 145/149 [============================>.] - ETA: 0s - loss: 4.4948e-07 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 4.4000e-07 - accuracy: 1.0000 - val_loss: 1.0511e-09 - val_accuracy: 1.0000
# Epoch 27/30
# 142/149 [===========================>..] - ETA: 0s - loss: 7.7365e-07 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 7.5132e-07 - accuracy: 1.0000 - val_loss: 6.1313e-10 - val_accuracy: 1.0000
# Epoch 28/30
# 142/149 [===========================>..] - ETA: 0s - loss: 5.7915e-07 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 5.6030e-07 - accuracy: 1.0000 - val_loss: 4.3795e-10 - val_accuracy: 1.0000
# Epoch 29/30
# 142/149 [===========================>..] - ETA: 0s - loss: 1.2095e-06 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.00000
# 149/149 [==============================] - 1s 5ms/step - loss: 1.1639e-06 - accuracy: 1.0000 - val_loss: 4.3795e-10 - val_accuracy: 1.0000
# Epoch 30/30
# 141/149 [===========================>..] - ETA: 0s - loss: 5.7626e-07 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00000 to 0.00000, saving model to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/hand_gesture_model_best.keras
# 149/149 [==============================] - 1s 5ms/step - loss: 5.9334e-07 - accuracy: 1.0000 - val_loss: 3.5036e-10 - val_accuracy: 1.0000

# %%
print("\nEvaluating on test data...")
test_loss, test_accuracy = model.evaluate(test_data)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Evaluating on test data...
# 22/22 [==============================] - 0s 3ms/step - loss: 1.2272e-09 - accuracy: 1.0000
# Test Loss: 0.0000
# Test Accuracy: 1.0000

# %%
y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for _, y in test_data], axis=0)
preds = model.predict(test_data, verbose=1)
y_pred = np.argmax(preds, axis=1)

# Create directories for saving model and results
os.makedirs(os.path.join(BASE_DIR, "models", "model_11"), exist_ok=True)
os.makedirs(os.path.join(BASE_DIR, "results", "model_11"), exist_ok=True)

# Print and save confusion matrix and classification report
cm = confusion_matrix(y_true, y_pred)
cr = classification_report(y_true, y_pred, target_names=class_names)
print("\nConfusion Matrix:\n", cm)
print("\nClassification Report:\n", cr)
with open(
    os.path.join(BASE_DIR, "results", "model_11", "classification_report.txt"), "w"
) as f:
    f.write("Confusion Matrix:\n")
    f.write(str(cm))
    f.write("\n\nClassification Report:\n")
    f.write(cr)

# Plot confusion matrix (raw counts) and normalized version
tick_marks = np.arange(len(class_names))

# Raw confusion matrix heatmap
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
plt.xticks(tick_marks, class_names, rotation=45, ha="right")
plt.yticks(tick_marks, class_names)
thresh = cm.max() / 2.0 if cm.size else 0
for i, j in np.ndindex(cm.shape):
    plt.text(
        j,
        i,
        f"{cm[i, j]:d}",
        ha="center",
        color="white" if cm[i, j] > thresh else "black",
    )
plt.ylabel("True label")
plt.xlabel("Predicted label")
plt.tight_layout()
plt.savefig(os.path.join(BASE_DIR, "results", "model_11", "confusion_matrix.png"))
plt.close()

# Normalized confusion matrix (rows sum to 1)
cm_norm = cm.astype("float")
row_sums = cm_norm.sum(axis=1)[:, np.newaxis]
with np.errstate(divide="ignore", invalid="ignore"):
    cm_norm = np.divide(cm_norm, row_sums)
cm_norm = np.nan_to_num(cm_norm)

plt.figure(figsize=(8, 6))
plt.imshow(cm_norm, interpolation="nearest", cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.colorbar()
plt.xticks(tick_marks, class_names, rotation=45, ha="right")
plt.yticks(tick_marks, class_names)
thresh = cm_norm.max() / 2.0 if cm_norm.size else 0
for i, j in np.ndindex(cm_norm.shape):
    plt.text(
        j,
        i,
        f"{cm_norm[i, j]:.2f}",
        ha="center",
        color="white" if cm_norm[i, j] > thresh else "black",
    )
plt.ylabel("True label")
plt.xlabel("Predicted label (normalized)")
plt.tight_layout()
plt.savefig(
    os.path.join(BASE_DIR, "results", "model_11", "confusion_matrix_normalized.png")
)
plt.close()

# Plot training curves
plt.figure()
plt.plot(history.history.get("loss", []), label="train_loss")
plt.plot(history.history.get("val_loss", []), label="val_loss")
plt.legend()
plt.title("Loss")
plt.savefig(os.path.join(BASE_DIR, "results", "model_11", "loss_curve.png"))
plt.close()

plt.figure()
plt.plot(history.history.get("accuracy", []), label="train_acc")
plt.plot(history.history.get("val_accuracy", []), label="val_acc")
plt.legend()
plt.title("Accuracy")
plt.savefig(os.path.join(BASE_DIR, "results", "model_11", "accuracy_curve.png"))
plt.close()

# Save the trained model
model_save_path = os.path.join(
    BASE_DIR, "models", "model_11", "hand_gesture_model_11.keras"
)
model.save(model_save_path)
print(f"\nModel saved to {model_save_path}")

# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open(os.path.join(BASE_DIR, "models", "model_11", "model_11.tflite"), "wb") as f:
    f.write(tflite_model)
# Out:
# 22/22 [==============================] - 0s 2ms/step
#
# Confusion Matrix:
#  [[85  0  0  0  0  0  0  0]
#  [ 0 85  0  0  0  0  0  0]
#  [ 0  0 85  0  0  0  0  0]
#  [ 0  0  0 85  0  0  0  0]
#  [ 0  0  0  0 85  0  0  0]
#  [ 0  0  0  0  0 85  0  0]
#  [ 0  0  0  0  0  0 85  0]
#  [ 0  0  0  0  0  0  0 85]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         left       1.00      1.00      1.00        85
#         none       1.00      1.00      1.00        85
#        right       1.00      1.00      1.00        85
#         spd1       1.00      1.00      1.00        85
#         spd2       1.00      1.00      1.00        85
#         spd3       1.00      1.00      1.00        85
#         spd4       1.00      1.00      1.00        85
#         stop       1.00      1.00      1.00        85
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
#
# Model saved to /Users/louismassingham/Documents/cnn-hand-gesture-classifier/models/model_11/hand_gesture_model_11.keras
# INFO:tensorflow:Assets written to: /var/folders/qg/vs03rg_n2p92q6n_gszm9_2r0000gn/T/tmpbb8_bwxv/assets
# INFO:tensorflow:Assets written to: /var/folders/qg/vs03rg_n2p92q6n_gszm9_2r0000gn/T/tmpbb8_bwxv/assets
# 2026-04-26 14:21:29.784826: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-04-26 14:21:29.784839: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 11, Total Ops 23, % non-converted = 47.83 %
#  * 11 ARITH ops
#
# - arith.constant:   11 occurrences  (f32: 10, i32: 1)
#
#
#
#   (f32: 3)
#   (f32: 2)
#   (f32: 2)
#   (f32: 1)
#   (f32: 1)
